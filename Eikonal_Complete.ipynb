# %% [markdown]
# # The problem
#
# Let $\Omega =  (-1,1)\times (-1,1)$, the problem is
#
# ---
#
# $$
# \begin{cases}
# |Du(x,y)|= 1 + \epsilon \Delta (x,y), & \qquad\text{for}\; (x,y)\in (-1,1)\times (-1,1),\\
# u(x,y) = 1 - \sqrt{x^2+y^2} , &\qquad\text{for}\; (x,y)\in \partial \Omega
# \end{cases}
# $$
#
# ---
#
# The exact solution is
#
# ---
#
# $$u(x,y) = 1 - \sqrt{x^2+y^2}$$
#
# ---
#
# The Loss is
#
# $$ L(\hat{u}) = \frac{1}{N^2}\sum_{j=1}^N\sum_{i=1}^N \Big(|D\hat{u}(x_i,y_j)|-1 - ϵ\Delta(x_i,y_j)\Big)^2$$

# %% [markdown]
# # Loading libraries

# %%
# Import libraries
import numpy as np
import math
from numpy import linalg
import pandas as pd
# !pip3 install torch==1.2.0+cu92 torchvision==0.4.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable

import torch.nn.init as init
from torch import autograd

from torch import nn, optim
from time import time

# %%
import matplotlib.pyplot as plt

# %%
N = 32
xs = torch.linspace(-1, 1, steps=N, requires_grad=True)
ys = torch.linspace(-1, 1, steps=N, requires_grad=True)
x, y = torch.meshgrid(xs, ys, indexing='xy')
[step_x, step_y] = [2/(N-1),2/(N-1)]

# %% [markdown]
# # Gradient functions

# %%
def gradient(u, step_x, step_y):
    # all inputs are (n*n)-dim pytorch tensor
    [Nx, Ny] = list(u.size())
    u_x_tensor = 0*u.clone()
    for row in range(1, Ny-1):
        u_x_tensor[row, 1:-1] = (-u[row, 0:-2] + u[row, 2:])/(2*step_x)
    u_y_tensor = 0*u.clone()
    for col in range(1, Nx-1):
        u_y_tensor[1:-1, col] = (-u[0:-2, col] + u[2:, col])/(2*step_y)
    return [u_x_tensor, u_y_tensor]    

def abs_grad(u, step_x, step_y):
    [u_x, u_y] = gradient(u, step_x, step_y)
    return torch.sqrt(torch.square(u_x) + torch.square(u_y))

def Laplacian(u, step_x, step_y):
    [Nx, Ny] = list(u.size())
    u_xx = 0*u.clone()
    for row in range(1, Ny-1):
        u_xx[row, 1:-1] = (u[row, 0:-2] + u[row, 2:] - 2*u[row, 1:-1])/(step_x**2)
    u_yy = 0*u.clone()
    for col in range(1, Nx-1):
        u_yy[1:-1, col] = (u[0:-2, col] + u[2:, col] - 2*u[1:-1, col])/(step_y**2)
    return (u_xx + u_yy)

# %% [markdown]
# # Loss function

# %%
def Loss(u, xs, ys, eps, step_x, step_y):
    [Nx, Ny] = list(u.size())
    # all inputs are (n*n)-dim pytorch tensor

    Delta_u = Laplacian(u, step_x, step_y)
    loss = nn.MSELoss()
    one_tensor = torch.ones(Nx, Ny, dtype=torch.float32)
    [u_x, u_y] = gradient(u, step_x, step_y)
    Du2 = u_x**2 + u_y**2
    result = loss(Du2[1:-1,1:-1] - eps*Delta_u[1:-1,1:-1], one_tensor[1:-1, 1:-1]) 
    return result

# %% [markdown]
# # Model

# %%
def PDEsNet(input_size=2, output_size=1, k=15):
    model = nn.Sequential(
        nn.Linear(input_size, k),
        nn.Tanh(),
        nn.Linear(k, k),
        nn.Tanh(),
        nn.Linear(k, k),
        nn.Tanh(),
        nn.Linear(k, output_size),
        nn.Tanh(),
                      )
    return model
# module5 = nn.Linear(hidden_sizes[3], hidden_sizes[4])
# init.xavier_normal_(module5.weight)

# %% [markdown]
# # Pack and Unpack

# %%
def unpack_column(xs, ys, Nx, Ny):
    x, y = torch.meshgrid(xs, ys, indexing='xy')
    # unpack_col = []
    for i in range(0, Nx):
        row_i = torch.stack([x[:,i],y[:,i]], dim=1)
        if i == 0:
            unpack_col = row_i
        else:    
            unpack_col = torch.vstack([unpack_col,row_i])
    return unpack_col

# %%
def pack_column(u, Nx, Ny):
    return torch.transpose(u.reshape((Nx, Ny)), 0, 1)

# %% [markdown]
# # Plot functions

# %%
def draw_loss(iter, loss, title='Loss'):
    plt.plot(iter, loss, '-b', label='loss')
    ##############################################
    plt.xlabel("n iteration")
    plt.legend(loc='upper left')
    plt.title(title)
    # save image
    plt.savefig(title +".png")  # should before show method
    # show
    plt.show()

def draw_graph(lst_iter, lst_loss, lst_acc, title):
    plt.plot(lst_iter, lst_loss, '-b', label='true')
    plt.plot(lst_iter, lst_acc, '-r', label='neural network')
    ##############################################
    plt.xlabel("x")
    plt.legend(loc='upper left')
    plt.title(title)
    plt.axis('off')
    
    # save image
    plt.savefig(title+".png")  # should before show method
    # show
    plt.show()

# %%
from PIL import Image

def save_gif_PIL(outfile, files, fps=5, loop=0):
    "Helper function for saving GIFs"
    "Credit: Ben Moseley"
    imgs = [Image.open(file) for file in files]
    imgs[0].save(fp=outfile, format='GIF', append_images=imgs[1:], 
                 save_all=True, duration=int(1000/fps), loop=loop)

def graph(x, y, u_hat):
    fig, ax = plt.subplots()
    ax = plt.axes(projection='3d')

    ax.set_ylabel('y')
    ax.set_xlabel('x')

    ax.set_zlim([0,1])

    # ax.grid(False)
    plt.axis('off')

    # Turn off tick labels
    ax.set_yticklabels([])
    ax.set_xticklabels([])

    X = x.detach().numpy()
    Y = y.detach().numpy()
    Z = u_hat.detach().numpy()

    ax.plot_surface(X, Y, Z,  
                    rstride=1, cstride=1,
                    cmap='winter', edgecolor='none')

# %% [markdown]
# # Training

# %%
[Nx, Ny] = [len(x), len(y)]

# %%
torch.manual_seed(111)
model = PDEsNet(input_size=2, output_size=1, k=8)
files = []

# %%
# torch.autograd.set_detect_anomaly(True)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
eps = 0.01
iter = []
loss_array = []
##############################################
num_e = 1000
for e in range(num_e):
    running_loss = 0
    optimizer.zero_grad() 
    ##############################################
    coordinates = unpack_column(xs, ys, Nx, Ny)
    u_hat_array = model(coordinates).clone() # need to not messed up the bakprop
    u_hat = pack_column(u_hat_array, Nx, Ny)
    # print(u_hat)

    # u_hat = 0*x*y
    # for i in range(1,Nx-1):
    #     for j in range(1, Ny-1):
    #         # print([xs[i], ys[j]])
    #         x_tensor = torch.tensor(np.array([xs[i].item(), ys[j].item()]), requires_grad= True)
    #         temp = model(x_tensor.float())
    #         u_hat[i, j] = temp

    # loss and backward
    u_star = 1-torch.sqrt(x**2 + y**2)
    u_hat[ 0, :] = u_star[ 0, :]
    u_hat[-1, :] = u_star[-1, :]
    u_hat[ :, 0] = u_star[ :, 0]
    u_hat[ :,-1] = u_star[ :,-1]
    # u_hat[0, :] *= 0
    # u_hat[-1,:] *= 0
    # u_hat[:, 0] *= 0
    # u_hat[:,-1] *= 0
    loss = Loss(u_hat, xs, ys, eps, step_x, step_y)
    loss.backward()
    optimizer.step() 
    ########################################################################
    running_loss += loss.clone().item()   
    loss_array.append(running_loss)
    iter.append(e)
    ########################################################################
    if ((e+1) % 10 == 0):
        print(f"The running loss at {(e):03d} iteration is: {running_loss}")

        graph(x, y, u_hat)
        file = "plots/nn_%.8e.png"%(e+1)
        plt.savefig(file, bbox_inches='tight', pad_inches=0.1, dpi=100, facecollor='white') 
        files.append(file)

        if (e+1)%500 == 0:
            plt.show()
        else:
            plt.close("all")
# Out:
# The running loss at 009 iteration is: 1.2423666715621948
# The running loss at 019 iteration is: 1.0035761594772339
# The running loss at 029 iteration is: 1.006044864654541
# The running loss at 039 iteration is: 0.9945629239082336
# The running loss at 049 iteration is: 0.9857535362243652
# The running loss at 059 iteration is: 0.9865730404853821
# The running loss at 069 iteration is: 0.9853556156158447
# The running loss at 079 iteration is: 0.9849278926849365
# The running loss at 089 iteration is: 0.9846423864364624
# The running loss at 099 iteration is: 0.9843071103096008
# The running loss at 109 iteration is: 0.9840318560600281
# The running loss at 119 iteration is: 0.9837397336959839
# The running loss at 129 iteration is: 0.9834534525871277
# The running loss at 139 iteration is: 0.9831627607345581
# The running loss at 149 iteration is: 0.9828709363937378
# The running loss at 159 iteration is: 0.9825767874717712
# The running loss at 169 iteration is: 0.9822805523872375
# The running loss at 179 iteration is: 0.9819818735122681
# The running loss at 189 iteration is: 0.981680691242218
# The running loss at 199 iteration is: 0.9813762307167053
# The running loss at 209 iteration is: 0.9810678362846375
# The running loss at 219 iteration is: 0.980755090713501
# The running loss at 229 iteration is: 0.9804367423057556
# The running loss at 239 iteration is: 0.9801119565963745
# The running loss at 249 iteration is: 0.9797796010971069
# The running loss at 259 iteration is: 0.9794383645057678
# The running loss at 269 iteration is: 0.9790866374969482
# The running loss at 279 iteration is: 0.9787227511405945
# The running loss at 289 iteration is: 0.9783450365066528
# The running loss at 299 iteration is: 0.9779513478279114
# The running loss at 309 iteration is: 0.9775391221046448
# The running loss at 319 iteration is: 0.9771057963371277
# The running loss at 329 iteration is: 0.9766483306884766
# The running loss at 339 iteration is: 0.9761630296707153
# The running loss at 349 iteration is: 0.9756461977958679
# The running loss at 359 iteration is: 0.975092887878418
# The running loss at 369 iteration is: 0.9744977355003357
# The running loss at 379 iteration is: 0.9738544821739197
# The running loss at 389 iteration is: 0.9731557965278625
# The running loss at 399 iteration is: 0.9723933935165405
# The running loss at 409 iteration is: 0.9715575575828552
# The running loss at 419 iteration is: 0.970637321472168
# The running loss at 429 iteration is: 0.9696200489997864
# The running loss at 439 iteration is: 0.9684913754463196
# The running loss at 449 iteration is: 0.9672357439994812
# The running loss at 459 iteration is: 0.965835452079773
# The running loss at 469 iteration is: 0.9642716646194458
# The running loss at 479 iteration is: 0.9625242948532104
# The running loss at 489 iteration is: 0.9605721831321716
# The running loss at 499 iteration is: 0.9583926796913147
# The running loss at 509 iteration is: 0.9559610486030579
# The running loss at 519 iteration is: 0.9532459378242493
# The running loss at 529 iteration is: 0.9502043724060059
# The running loss at 539 iteration is: 0.9467693567276001
# The running loss at 549 iteration is: 0.9428313374519348
# The running loss at 559 iteration is: 0.9382081031799316
# The running loss at 569 iteration is: 0.9325916767120361
# The running loss at 579 iteration is: 0.9254538416862488
# The running loss at 589 iteration is: 0.9158521294593811
# The running loss at 599 iteration is: 0.9019623398780823
# The running loss at 609 iteration is: 0.879460871219635
# The running loss at 619 iteration is: 0.8330187201499939
# The running loss at 629 iteration is: 0.7343026995658875
# The running loss at 639 iteration is: 0.5830044746398926
# The running loss at 649 iteration is: 0.422947496175766
# The running loss at 659 iteration is: 0.31114426255226135
# The running loss at 669 iteration is: 0.2558465301990509
# The running loss at 679 iteration is: 0.23773439228534698
# The running loss at 689 iteration is: 0.2328985035419464
# The running loss at 699 iteration is: 0.22905859351158142
# The running loss at 709 iteration is: 0.2254219502210617
# The running loss at 719 iteration is: 0.22194644808769226
# The running loss at 729 iteration is: 0.2187734991312027
# The running loss at 739 iteration is: 0.21589596569538116
# The running loss at 749 iteration is: 0.21330691874027252
# The running loss at 759 iteration is: 0.2109510600566864
# The running loss at 769 iteration is: 0.20876304805278778
# The running loss at 779 iteration is: 0.20666161179542542
# The running loss at 789 iteration is: 0.2045530527830124
# The running loss at 799 iteration is: 0.20232856273651123
# The running loss at 809 iteration is: 0.19988147914409637
# The running loss at 819 iteration is: 0.19716288149356842
# The running loss at 829 iteration is: 0.19423839449882507
# The running loss at 839 iteration is: 0.19126436114311218
# The running loss at 849 iteration is: 0.1883833408355713
# The running loss at 859 iteration is: 0.18565474450588226
# The running loss at 869 iteration is: 0.18307486176490784
# The running loss at 879 iteration is: 0.18062137067317963
# The running loss at 889 iteration is: 0.1782679259777069
# The running loss at 899 iteration is: 0.17597898840904236
# The running loss at 909 iteration is: 0.1737087368965149
# The running loss at 919 iteration is: 0.17140403389930725
# The running loss at 929 iteration is: 0.168989360332489
# The running loss at 939 iteration is: 0.1661757230758667
# The running loss at 949 iteration is: 0.1596831977367401
# The running loss at 959 iteration is: 0.14649492502212524
# The running loss at 969 iteration is: 0.13833625614643097
# The running loss at 979 iteration is: 0.13354459404945374
# The running loss at 989 iteration is: 0.12974363565444946
# The running loss at 999 iteration is: 0.12707598507404327

# %%
save_gif_PIL("nn.gif", files, fps=20, loop=0)
draw_loss(iter, loss_array, title='Loss')

# %% [markdown]
# # Plot

# %%
import webbrowser
webbrowser.open('/content/nn.gif')
# Out:
# False

# %%
from mpl_toolkits import mplot3d

fig, ax = plt.subplots()
ax = plt.axes(projection='3d')

ax.set_ylabel('y')
ax.set_xlabel('x')

# Turn off tick labels
ax.set_yticklabels([])
ax.set_xticklabels([])

X = x.detach().numpy()
Y = y.detach().numpy()
Z = u_hat.detach().numpy()
# ax.plot_surface(x.detach().numpy(), y.detach().numpy(), u_hat.detach().numpy())
ax.plot_surface(X, Y, Z,  
                rstride=1, cstride=1,
                cmap='winter', edgecolor='none')

# %%
from mpl_toolkits import mplot3d

fig, ax = plt.subplots()
ax = plt.axes(projection='3d')

ax.set_ylabel('y')
ax.set_xlabel('x')

# Turn off tick labels
ax.set_yticklabels([])
ax.set_xticklabels([])

X = x.detach().numpy()
Y = y.detach().numpy()
Z = u_star.detach().numpy()
# ax.plot_surface(x.detach().numpy(), y.detach().numpy(), u_hat.detach().numpy())
ax.plot_surface(X, Y, Z,  
                rstride=1, cstride=1,
                cmap='winter', edgecolor='none')

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Surface(z=Z, x=X, y=Y, colorscale="Reds", opacity=0.5)])
fig.update_layout(
    title='My title', 
    autosize=False,
    width=500, 
    height=500,
    margin=dict(l=65, r=50, b=65, t=90), 
    scene_aspectmode='cube'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="44865346-186e-4d6f-89bd-8ae668c99556" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("44865346-186e-4d6f-89bd-8ae668c99556")) {
#                     Plotly.newPlot(
#                         '44865346-186e-4d6f-89bd-8ae668c99556',
#                         [{"colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]],